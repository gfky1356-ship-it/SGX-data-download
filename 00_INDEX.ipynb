# %% [markdown]
# # Stock Scanner — Notebook Index
#
# Click a link below to open that notebook in Colab.
# Each notebook is **standalone** — run only what you need.
#
# ---
#
# ### 1. SGX Historical Data Downloader
# Downloads 1-year SGX price history for all ~558 stocks via Yahoo Finance.
# [▶ Open in Colab](https://colab.research.google.com/github/gfky1356-ship-it/SGX-data-download/blob/main/01_SGX_Downloader.ipynb)
#
# ---
#
# ### 2. SGX Stock Scanner
# Scans SGX stocks using SMA Gap, Breakout, and OBV signals.
# Filters: volume > 100,000 and price > S$0.20.
# [▶ Open in Colab](https://colab.research.google.com/github/gfky1356-ship-it/SGX-data-download/blob/main/02_SGX_Scanner.ipynb)
#
# ---
#
# ### 3. S&P 500 Historical Data Downloader
# Downloads 1-year price history for all ~503 S&P 500 stocks via Yahoo Finance.
# [▶ Open in Colab](https://colab.research.google.com/github/gfky1356-ship-it/SGX-data-download/blob/main/03_SP500_Downloader.ipynb)
#
# ---
#
# ### 4. S&P 500 Stock Scanner
# Scans S&P 500 stocks using SMA Gap, Breakout, and OBV signals against SPY benchmark.
# [▶ Open in Colab](https://colab.research.google.com/github/gfky1356-ship-it/SGX-data-download/blob/main/04_SP500_Scanner.ipynb)
#
# ---
#
# ### 5. S&P 500 RSI Strength + 52-Week High Scanner
# Finds S&P 500 stocks where RSI(14) beats SPY by ≥5 pts, price within 2% of 52-week high, and within 10% of 50-day SMA.
# [▶ Open in Colab](https://colab.research.google.com/github/gfky1356-ship-it/SGX-data-download/blob/main/05_SP500_RSI_Scanner.ipynb)
